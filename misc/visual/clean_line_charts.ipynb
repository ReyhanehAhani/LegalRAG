# %%
import matplotlib.pyplot as plt
import pandas as pd

# mistral hierarchical chunking results
k_values = [2, 4, 6, 10, 15, 20, 40, 60]
model_order = ['SBERT (all-mpnet-base-v2)', 'Legal-Embed-bge-base', 'LegalBERT', 'BERT-DPR-CLERC-ft', 'Octen', 'Qwen3']
model_colors = {
    'SBERT (all-mpnet-base-v2)': 'blue',
    'Legal-Embed-bge-base': 'green',
    'LegalBERT': 'red',
    'BERT-DPR-CLERC-ft': 'purple',
    'Octen': 'orange',
    'Qwen3': 'pink'
}
markers = ['o', 's', '^', 'D', 'v', '*']
linestyles = ['-', '--', '-.', ':', '-', '--']

mistral_data = {
    'SBERT (all-mpnet-base-v2)': {
        'recall': [0.0350, 0.0821, 0.1127, 0.1494, 0.1796, 0.2000, 0.2703, 0.3088],
        'precision': [0.0200, 0.0244, 0.0231, 0.0192, 0.0168, 0.0142, 0.0108, 0.0084]
    },
    'Legal-Embed-bge-base': {
        'recall': [0.0393, 0.0644, 0.0951, 0.1280, 0.1706, 0.1901, 0.2554, 0.2876],
        'precision': [0.0174, 0.0174, 0.0171, 0.0153, 0.0141, 0.0128, 0.0098, 0.0077]
    },
    'LegalBERT': {
        'recall': [0.0075, 0.0310, 0.0368, 0.0511, 0.0688, 0.0838, 0.1210, 0.1454],
        'precision': [0.0052, 0.0103, 0.0085, 0.0065, 0.0058, 0.0052, 0.0042, 0.0036]
    },
    'BERT-DPR-CLERC-ft': {
        'recall': [0.0174, 0.0275, 0.0383, 0.0484, 0.0679, 0.0819, 0.1230, 0.1480],
        'precision': [0.0092, 0.0090, 0.0089, 0.0070, 0.0061, 0.0060, 0.0046, 0.0039]
    },
    'Octen': {
        'recall': [0.0424, 0.0872, 0.1054, 0.1494, 0.1929, 0.2236, 0.2737, 0.3057],
        'precision': [0.0201, 0.0221, 0.0204, 0.0180, 0.0175, 0.0161, 0.0108, 0.0085]
    },
    'Qwen3': {
        'recall': [0.0487, 0.0707, 0.0972, 0.1334, 0.1624, 0.2043, 0.2635, 0.3119],
        'precision': [0.0221, 0.0177, 0.0186, 0.0165, 0.0155, 0.0143, 0.0103, 0.0084]
    }
}

recall_ylim = [0, 0.35]
precision_ylim = [0, 0.035]
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})

# Plot Recall
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, mistral_data[model]['recall'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(recall_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharRecall@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Recall@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper left', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('mistral_hierarchical_recall_all6.png', dpi=300)

# Plot Precision
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, mistral_data[model]['precision'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(precision_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharPrecision@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Precision@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper right', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('mistral_hierarchical_precision_all6.png', dpi=300)

# %%
import matplotlib.pyplot as plt


# orginal query
k_values = [2, 4, 6, 10, 15, 20, 40, 60]
model_order = ['SBERT (all-mpnet-base-v2)', 'Legal-Embed-bge-base', 'LegalBERT', 'BERT-DPR-CLERC-ft', 'Octen', 'Qwen3']
model_colors = {
    'SBERT (all-mpnet-base-v2)': 'blue',
    'Legal-Embed-bge-base': 'green',
    'LegalBERT': 'red',
    'BERT-DPR-CLERC-ft': 'purple',
    'Octen': 'orange',
    'Qwen3': 'pink'
}
markers = ['o', 's', '^', 'D', 'v', '*']
linestyles = ['-', '--', '-.', ':', '-', '--']

# Data extraction from the uploaded "Original" run images
original_data = {
    'SBERT (all-mpnet-base-v2)': {
        'recall': [0.0432, 0.0758, 0.1024, 0.1380, 0.1669, 0.1983, 0.2689, 0.2899],
        'precision': [0.0291, 0.0250, 0.0209, 0.0168, 0.0148, 0.0142, 0.0108, 0.0081]
    },
    'Legal-Embed-bge-base': {
        'recall': [0.0318, 0.0506, 0.0843, 0.1058, 0.1497, 0.1819, 0.2603, 0.3099],
        'precision': [0.0167, 0.0167, 0.0180, 0.0147, 0.0134, 0.0120, 0.0103, 0.0084]
    },
    'LegalBERT': {
        'recall': [0.0090, 0.0209, 0.0439, 0.0798, 0.0947, 0.1097, 0.1398, 0.1661],
        'precision': [0.0062, 0.0074, 0.0098, 0.0107, 0.0086, 0.0082, 0.0054, 0.0044]
    },
    'BERT-DPR-CLERC-ft': {
        'recall': [0.0222, 0.0421, 0.0477, 0.0684, 0.0836, 0.1007, 0.1335, 0.1569],
        'precision': [0.0099, 0.0110, 0.0100, 0.0091, 0.0083, 0.0074, 0.0052, 0.0042]
    },
    'Octen': {
        'recall': [0.0475, 0.0666, 0.1002, 0.1360, 0.1716, 0.2051, 0.2894, 0.3155],
        'precision': [0.0268, 0.0212, 0.0195, 0.0171, 0.0150, 0.0147, 0.0118, 0.0090]
    },
    'Qwen3': {
        'recall': [0.0400, 0.0692, 0.0731, 0.1271, 0.1598, 0.1848, 0.2597, 0.2991],
        'precision': [0.0217, 0.0191, 0.0140, 0.0160, 0.0150, 0.0143, 0.0109, 0.0084]
    }
}

recall_ylim = [0, 0.35]
precision_ylim = [0, 0.035]
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})

# Plot Recall
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, original_data[model]['recall'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(recall_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharRecall@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Recall@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper left', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('original_hierarchical_recall_all6.png', dpi=300)

# Plot Precision
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, original_data[model]['precision'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(precision_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharPrecision@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Precision@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper right', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('original_hierarchical_precision_all6.png', dpi=300)

# %%
# qwen 2.5 query
import matplotlib.pyplot as plt

k_values = [2, 4, 6, 10, 15, 20, 40, 60]
model_order = ['SBERT (all-mpnet-base-v2)', 'Legal-Embed-bge-base', 'LegalBERT', 'BERT-DPR-CLERC-ft', 'Octen', 'Qwen3']
model_colors = {
    'SBERT (all-mpnet-base-v2)': 'blue',
    'Legal-Embed-bge-base': 'green',
    'LegalBERT': 'red',
    'BERT-DPR-CLERC-ft': 'purple',
    'Octen': 'orange',
    'Qwen3': 'pink'
}
markers = ['o', 's', '^', 'D', 'v', '*']
linestyles = ['-', '--', '-.', ':', '-', '--']

# Data extraction for the "qwen2.5" run from the provided images
qwen25_data = {
    'SBERT (all-mpnet-base-v2)': {
        'recall': [0.0480, 0.0845, 0.1011, 0.1304, 0.1604, 0.1779, 0.2371, 0.2866],
        'precision': [0.0291, 0.0254, 0.0203, 0.0161, 0.0142, 0.0131, 0.0093, 0.0081]
    },
    'Legal-Embed-bge-base': {
        'recall': [0.0185, 0.0730, 0.1009, 0.1313, 0.1443, 0.1576, 0.2184, 0.2557],
        'precision': [0.0140, 0.0194, 0.0186, 0.0156, 0.0125, 0.0108, 0.0083, 0.0070]
    },
    'LegalBERT': {
        'recall': [0.0091, 0.0216, 0.0284, 0.0408, 0.0619, 0.0800, 0.1103, 0.1302],
        'precision': [0.0064, 0.0063, 0.0061, 0.0051, 0.0053, 0.0053, 0.0037, 0.0030]
    },
    'BERT-DPR-CLERC-ft': {
        'recall': [0.0118, 0.0216, 0.0325, 0.0465, 0.0612, 0.0722, 0.1075, 0.1318],
        'precision': [0.0078, 0.0079, 0.0077, 0.0061, 0.0053, 0.0048, 0.0037, 0.0032]
    },
    'Octen': {
        'recall': [0.0417, 0.0761, 0.1076, 0.1399, 0.1671, 0.1854, 0.2731, 0.3143],
        'precision': [0.0220, 0.0202, 0.0198, 0.0162, 0.0142, 0.0127, 0.0105, 0.0087]
    },
    'Qwen3': {
        'recall': [0.0400, 0.0801, 0.1026, 0.1309, 0.1683, 0.1985, 0.2518, 0.2965],
        'precision': [0.0209, 0.0207, 0.0183, 0.0152, 0.0139, 0.0132, 0.0098, 0.0081]
    }
}

recall_ylim = [0, 0.35]
precision_ylim = [0, 0.035]
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})

# Plot Recall
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, qwen25_data[model]['recall'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(recall_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharRecall@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Recall@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper left', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('qwen2.5_hierarchical_recall_all6.png', dpi=300)

# Plot Precision
plt.figure(figsize=(10, 7))
for i, model in enumerate(model_order):
    plt.plot(k_values, qwen25_data[model]['precision'], label=model, color=model_colors[model],
             marker=markers[i], linestyle=linestyles[i], linewidth=2.5, markersize=8)
plt.ylim(precision_ylim)
plt.xlabel('K (Retrieval Depth)', fontsize=12, fontweight='bold')
plt.ylabel('Overall CharPrecision@K (Macro-Avg)', fontsize=12, fontweight='bold')
plt.title('Character-Level Precision@K Comparison', fontsize=14, fontweight='bold')
plt.legend(loc='upper right', frameon=True, shadow=True, fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.savefig('qwen2.5_hierarchical_precision_all6.png', dpi=300)
